# %% [markdown]
# Using Python to find all the permutations I need to consider for screens

# %%
import itertools

# %%
categories = ["t", "n", "c", "o","q"]

# %%
combo1 = list(itertools.combinations(categories, 1))
combo1
# Out:
# [('t',), ('n',), ('c',), ('o',), ('q',)]

# %%
combo2 = list(itertools.combinations(categories,2))
combo2
# Out:
# [('t', 'n'),
#  ('t', 'c'),
#  ('t', 'o'),
#  ('t', 'q'),
#  ('n', 't'),
#  ('n', 'c'),
#  ('n', 'o'),
#  ('n', 'q'),
#  ('c', 't'),
#  ('c', 'n'),
#  ('c', 'o'),
#  ('c', 'q'),
#  ('o', 't'),
#  ('o', 'n'),
#  ('o', 'c'),
#  ('o', 'q'),
#  ('q', 't'),
#  ('q', 'n'),
#  ('q', 'c'),
#  ('q', 'o')]
